# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.genfromtxt('data.csv', delimiter=',')

# %%
plt.plot(data, 'bo')
plt.ylabel('some numbers')
plt.show()

# %%
def f(x, weight, bias):
    return weight * x + bias

# %%
def step_gradient(b_current, m_current, points, learningRate):
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learningRate * b_gradient)
    new_m = m_current - (learningRate * m_gradient)
    return new_b, new_m

# %%
m = 0
b = 0

values = []
for i in range(10):
    b, m = step_gradient(b, m, data, 0.0001) 
    values.append([b, m])

# %%
line_data_x = np.arange(100)

lines = []
for b_, m_ in values:
    lines.append([f(x_, m_, b_) for x_ in line_data_x])

#print(lines)

# %%
plt.plot(data, 'bo')
plt.ylabel('y')

for line in lines:
    plt.plot(line)
    
plt.show()
